# %% [markdown]
# ## plot customization by hand
# Throughout this chapter, we’ve seen how it is possible to tweak individual plot settings to end up with something that looks a little bit nicer than the default. It’s possible to do these customizations for each individual plot. For example, here is a fairly drab default histogram

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.style.use('classic')

# %%
x=np.random.randn(1000)
plt.hist(x)
print("histogram in matplotlib's default style")
# Out:
# histogram in matplotlib's default style

# %%
# use a gray background
#ax=plt.axes(axisbg='#E6E6E6') 
ax = plt.axes(fc='yellow') # fc='red'
ax.set_axisbelow(True)

#draw solid white grid lines
plt.grid(color='w' ,linestyle='solid')

# hide axis spines
for spine in ax.spines.values():
    spine.set_visible(False)

# hide top and right ticks
ax.xaxis.tick_bottom()
ax.yaxis.tick_left()

#lighten ticks and labels
ax.tick_params(colors='gray',direction='out')
for tick in ax.get_xticklabels():
    tick.set_color('red')
for tick in ax.get_yticklabels():
    tick.set_color('blue')
    
#control face and edge color of histogram
ax.hist(x,edgecolor='orange',color='green')
print("Adjust this by hand to make more visually pleasing plot")
# Out:
# Adjust this by hand to make more visually pleasing plot

# %% [markdown]
# ## chanigling the default : rc Params

# %% [markdown]
# Each time Matplotlib loads, it defines a runtime configuration (rc) containing the default styles for every plot element you create. You can adjust this configuration at any time using the plt.rc convenience routine. Let’s see what it looks like to modify the rc parameters so that our default plot will look similar to what we did before.
#
# We’ll start by saving a copy of the current rcParams dictionary, so we can easily reset these changes in the current session:

# %%
IPython_default=plt.rcParams.copy()
IPython_default
# Out:
# {'_internal.classic_mode': True,
#  'agg.path.chunksize': 0,
#  'animation.avconv_args': [],
#  'animation.avconv_path': 'avconv',
#  'animation.bitrate': -1,
#  'animation.codec': 'mpeg4',
#  'animation.convert_args': [],
#  'animation.convert_path': 'convert',
#  'animation.embed_limit': 20.0,
#  'animation.ffmpeg_args': [],
#  'animation.ffmpeg_path': 'ffmpeg',
#  'animation.frame_format': 'png',
#  'animation.html': 'none',
#  'animation.html_args': [],
#  'animation.writer': 'ffmpeg',
#  'axes.autolimit_mode': 'round_numbers',
#  'axes.axisbelow': True,
#  'axes.edgecolor': 'none',
#  'axes.facecolor': '#E6E6E6',
#  'axes.formatter.limits': [-7, 7],
#  'axes.formatter.min_exponent': 0,
#  'axes.formatter.offset_threshold': 2,
#  'axes.formatter.use_locale': False,
#  'axes.formatter.use_mathtext': False,
#  'axes.formatter.useoffset': True,
#  'axes.grid': True,
#  'axes.grid.axis': 'both',
#  'axes.grid.which': 'major',
#  'axes.labelcolor': 'k',
#  'axes.labelpad': 5.0,
# ...

# %%
# now create use the plt.rc function ro change setting
from matplotlib import cycler
colors=cycler('color',['#EE6666', '#3388BB', '#9988DD',
                       '#EECC55', '#88BB44', '#FFBBBB'])
plt.rc('axes',facecolor='#E6E6E6',edgecolor='none',
      axisbelow=True,grid=True,prop_cycle=colors)
plt.rc('grid',color='yellow',linestyle='solid')
plt.rc('xtick',direction='out',color='gray')
plt.rc('ytick',direction='out',color='blue')
plt.rc('patch',edgecolor='yellow')
plt.rc('lines',linewidth=2)
# our setting in action
plt.hist(x)
# Out:
# (array([  5.,  27.,  59., 147., 231., 244., 162.,  86.,  30.,   9.]),
#  array([-3.06619067, -2.46679524, -1.86739982, -1.26800439, -0.66860897,
#         -0.06921354,  0.53018188,  1.1295773 ,  1.72897273,  2.32836815,
#          2.92776358]),
#  <a list of 10 Patch objects>)

# %%
# simple line plots look like these rc parameter
for i in range(4):
    plt.plot(np.random.rand(10))

# %% [markdown]
# # Stylesheets
# The version 1.4 release of Matplotlib in August 2014 added a very convenient style module, which includes a number of new default stylesheets, as well as the ability to create and package your own styles. These stylesheets are formatted similarly to the .matplotlibrc files mentioned earlier, but must be named with a .mplstyle extension.

# %%
plt.style.available[:5]
# Out:
# ['bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight']

# %%
# create a function that will make two basic type of plot
def hist_and_lines():
    np.random.seed(0)
    fig,ax=plt.subplots(1,2,figsize=(11,4))
    ax[0].hist(np.random.randn(1000))
    for i in range(3):
        ax[1].plot(np.random.rand(10))
    ax[1].legend(['a','b','c'],loc='lower left')

# %%
hist_and_lines()

# %%
# Default style
# reset rcParam
# plt.rcParams.update(IPython_default)

# %% [markdown]
# ## Five Thirty Eight Style

# %%
with plt.style.context('fivethirtyeight'):
    hist_and_lines()

# %% [markdown]
# ## ggplot
# The ggplot package in R language is very popular visualization tool

# %%
with plt.style.context('ggplot'):
    hist_and_lines()

# %% [markdown]
# ## Bayesian method for Hacker style
# There is a very nice short online book called <b>Probabilistic Programming and Bayesian Methods for Hackers </b>; it features figures created with Matplotlib, and uses a nice set of rc parameters to create a consistent and visually appealing style throughout the book. This style is reproduced in the <b>bmh</b> stylesheet

# %%
with plt.style.context('bmh'):
    hist_and_lines()

# %% [markdown]
# ## Dark Background
# for presentation purpose ,it is useful to have a dark rather than light background

# %%
with plt.style.context('dark_background'):
    hist_and_lines()

# %% [markdown]
# ## Gray Scale
# for print purpose , if the color image not accept then it is better to choose gray scale style

# %%
with plt.style.context('grayscale'):
    hist_and_lines()

# %% [markdown]
# ## Seaborn style

# %%
with plt.style.context('seaborn'):
    hist_and_lines()
